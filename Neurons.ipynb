# %% [markdown]
# # What is the output the neuron?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X=7
W=1.5
b=3

# %%
fnet=(X*W)+b

# %%
def f(fnet):
   return(fnet**2)+8

# %%
f(fnet)
# Out:
# 190.25

# %% [markdown]
# # What is the output the neuron?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x1=7
x2=5
x3=2

# %%
w1=1.5
w2=4
w3=3
b=3

# %%
fnet=x1*w1+x2*w2+x3*w3+b

# %%
def f(fnet):
 return (fnet**2)+8

# %%
f(fnet)
# Out:
# 1568.25
